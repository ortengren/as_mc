# %%
import ase.io
import ase
import matplotlib.pyplot as plt
import numpy as np
from numpy.linalg import cross
from metropolis import MetropolisCalculator

from measurements import *

# %%
frames = ase.io.read("xyz_files/duped_ellipsoids_with_axes.xyz", ":")

# %%
metro = MetropolisCalculator(frames[0])
metro.calculate_trajectory(2_000)
# Out:
# 100  /  2000
# acc_rate: 0.82
# or_delt: 0.20000000000000004 -> 0.30000000000000004
# pos_delt: 0.20000000000000004 -> 0.30000000000000004
# 200  /  2000
# acc_rate: 0.76
# or_delt: 0.30000000000000004 -> 0.4
# pos_delt: 0.30000000000000004 -> 0.4
# 300  /  2000
# acc_rate: 0.8
# or_delt: 0.4 -> 0.5
# pos_delt: 0.4 -> 0.5
# 400  /  2000
# acc_rate: 0.8
# or_delt: 0.5 -> 0.6
# pos_delt: 0.5 -> 0.6
# 500  /  2000
# acc_rate: 0.7
# or_delt: 0.6 -> 0.7
# pos_delt: 0.6 -> 0.7
# 600  /  2000
# acc_rate: 0.74
# or_delt: 0.7 -> 0.7999999999999999
# pos_delt: 0.7 -> 0.7999999999999999
# 700  /  2000
# acc_rate: 0.76
# or_delt: 0.7999999999999999 -> 0.8999999999999999
# pos_delt: 0.7999999999999999 -> 0.8999999999999999
# 800  /  2000
# acc_rate: 0.76
# or_delt: 0.8999999999999999 -> 0.9999999999999999
# pos_delt: 0.8999999999999999 -> 0.9999999999999999
# 900  /  2000
# acc_rate: 0.65
# or_delt: 0.9999999999999999 -> 1.0999999999999999
# pos_delt: 0.9999999999999999 -> 1.0999999999999999
# ...

# %%
metro.get_acc_rate()
# Out:
# 0.9035

# %%
ase.io.write("simulations/testing/duped_ell_gb_test_1.xyz", metro.frames)
